# %%
import os
import numpy as np
import scanpy as sc

data_dir = '/hdd/jupyter/brad/scenicplus/motor-pathway_multiome/motor-pathway_multiome_seurat_cellbender.0.05_preprocess_cr/data/'
work_dir = '/hdd/jupyter/brad/scenicplus/motor-pathway_multiome/motor-pathway_multiome_seurat_cellbender.0.05_preprocess_cr/ra-arco-hvc-nc_seurat-snrna-clustering/anndata_rna/'
adata_fname = os.path.join(data_dir, "adata.h5ad")

# %%
adata = sc.read_h5ad(adata_fname)

# %%
conditions = [(adata.obs.position.str.contains('arco|ra')),
              (adata.obs.position.str.contains('nc|hvc'))]
choices = ['arco', 'nido']
adata.obs['region'] = np.select(conditions, choices)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 17334 × 15948
#     obs: 'cluster', 'position', 'assignment', 'sample_short', 'run', 'replicate', 'region'
#     var: 'name'
#     obsm: 'X_umap_rna_int'

# %%
adata.obs.region.value_counts()
# Out:
# nido    11661
# arco     5673
# Name: region, dtype: int64

# %%
regions = ['arco', 'nido']

for region in regions:
    adata_sub = adata[adata.obs.region == region,:]
    adata_out_fname = os.path.join(work_dir, f'{region}.h5ad')
    adata_sub.write_h5ad(adata_out_fname)
# Out:
# /home/brad/micromamba/envs/scenicplus/lib/python3.11/site-packages/anndata/_core/anndata.py:1301: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c

# %%
adata_arco = sc.read_h5ad(os.path.join(work_dir, 'arco.h5ad'))
